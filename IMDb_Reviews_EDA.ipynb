# %% [markdown]
# ## __Project 1:__ Text Data EDA (IMDb Movie Reviews)
#
# ### __Objective:__
# - The objective of this project is to perform a comprehensive exploratory analysis of 50,000 IMDb movie reviews, uncover patterns in text data, and derive insights regarding sentiment trends. This project establishes a foundation in data handling, text analytics, and visualization, preparing for advanced applications in Natural Language Processing and Generative AI.
#
# ### __Dataset:__
# - **IMDb Movie Reviews** – 50,000 reviews labeled as positive or negative.
# - **Source:** [IMDb 50K Movie Reviews Dataset on Kaggle](https://www.kaggle.com/datasets/lakshmi25npathi/imdb-dataset-of-50k-movie-reviews)
# - **Format:** CSV (`IMDB Dataset.csv`)
#
# ### __Skills Learned:__
# - Data loading, inspection, and cleaning using pandas
# - Text statistics, including review length and word counts
# - Exploratory text analysis and keyword insights
# - Data visualization using matplotlib and seaborn
# - Preparation for sentiment analysis and NLP tasks

# %% [markdown]
# ## __Workflow__
# ### __1. Load and Inspect Dataset__
# - Load CSV using pandas
# - Inspect the structure, data types, and sample records

# %%
import pandas as pd
df = pd.read_csv(r"C:\Users\BDO NARKANDA\Downloads\IMDB Dataset.csv.zip")

# Inspect dataset
print(df.head())
print(df.info())
print(df.shape)
# Out:
#                                               review sentiment
# 0  One of the other reviewers has mentioned that ...  positive
# 1  A wonderful little production. <br /><br />The...  positive
# 2  I thought this was a wonderful way to spend ti...  positive
# 3  Basically there's a family where a little boy ...  negative
# 4  Petter Mattei's "Love in the Time of Money" is...  positive
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 50000 entries, 0 to 49999
# Data columns (total 2 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   review     50000 non-null  object
#  1   sentiment  50000 non-null  object
# dtypes: object(2)
# memory usage: 781.4+ KB
# None
# (50000, 2)

# %% [markdown]
# ### __2. Missing Values Check__
# - Identify and handle any missing or null values to ensure dataset integrity

# %%
print(df.isnull().sum())
# Out:
# review       0
# sentiment    0
# dtype: int64

# %% [markdown]
# ### __3. Text Statistics__
# - Compute review lengths (number of characters)
# - Summarize key metrics such as mean, min, and max review lengths

# %%
# Add column for review length
df['review_length'] = df['review'].apply(len)

# Summary statistics
print(df['review_length'].describe())
# Out:
# count    50000.000000
# mean      1309.431020
# std        989.728014
# min         32.000000
# 25%        699.000000
# 50%        970.000000
# 75%       1590.250000
# max      13704.000000
# Name: review_length, dtype: float64

# %% [markdown]
# ### __4. Data Visualization__
# - Histogram of review lengths to understand distribution
# - Bar chart for sentiment distribution (positive vs negative)

# %%
import matplotlib.pyplot as plt

plt.hist(df['review_length'], bins=50, color='skyblue')
plt.xlabel('Review Length')
plt.ylabel('Frequency')
plt.title('Distribution of Review Lengths')
plt.show()

# %% [markdown]
# ### __5. Exploratory Text Analysis__
# - Keyword frequency analysis
# - Compare average review lengths by sentiment
# - Optional: word clouds for positive vs negative reviews

# %%
import seaborn as sns

sns.countplot(x='sentiment', data=df)
plt.title('Sentiment Distribution')
plt.show()

# %% [markdown]
# ### __#Tools and Libraries__
# - Python
# - pandas
# - matplotlib
# - seaborn
#
# ### __Conclusion__
#
# This project demonstrates the ability to systematically explore and analyze text data from a large-scale real-world dataset. By conducting statistical analysis, visualization, and keyword exploration, meaningful insights regarding review patterns and sentiment trends were derived. The balanced sentiment distribution and identified text patterns highlight the dataset’s suitability for NLP, sentiment classification, and Generative AI projects. This work reflects proficiency in data handling, exploratory analysis, and actionable insight generation, making it a strong addition to a professional portfolio.
